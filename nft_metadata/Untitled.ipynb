# %%
import random
import json
import os

# %%
types = ['Brown dwarf', 'Chthonian planet', 'Eccentric Jupiter', 'Gas giant', 'Helium planet', 'Ammonia planet', 'Carbon planet',
       'Earth analog', 'Forest planet', 'Ocean planet']
pweights = [52.5, 20, 10, 5, 4, 3, 2, 2, 1, 0.5]

# %%
sum(pweights)
# Out:
# 100.0

# %%
all_planets = []

# %%
def create_new_planet(n):
        all_planets = []
        for j in range(n):
            for i in range(1,16):
                new_planet = {}
                if i == 1:
                    new_planet["size"] = random.randrange(94,172)
                    new_planet["temperature"] = random.randrange(220, 260)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 2:
                    new_planet["size"] = random.randrange(104,176)
                    new_planet["temperature"] = random.randrange(170, 210)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 3:
                    new_planet["size"] = random.randrange(112,182)
                    new_planet["temperature"] = random.randrange(120, 160)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 4:
                    new_planet["size"] = random.randrange(118,208)
                    new_planet["temperature"] = random.randrange(70, 110)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 5:
                    new_planet["size"] = random.randrange(133,232)
                    new_planet["temperature"] = random.randrange(60, 100)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 6:
                    new_planet["size"] = random.randrange(146,242)
                    new_planet["temperature"] = random.randrange(70, 90)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 7:
                    new_planet["size"] = random.randrange(152,248)
                    new_planet["temperature"] = random.randrange(40, 80)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 8:
                    new_planet["size"] = random.randrange(156,242)
                    new_planet["temperature"] = random.randrange(30, 70)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 9:
                    new_planet["size"] = random.randrange(150,246)
                    new_planet["temperature"] = random.randrange(20,60)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 10:
                    new_planet["size"] = random.randrange(142,232)
                    new_planet["temperature"] = random.randrange(10, 50)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 11:
                    new_planet["size"] = random.randrange(136,210)
                    new_planet["temperature"] = random.randrange(0, 40)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 12:
                    new_planet["size"] = random.randrange(125,186)
                    new_planet["temperature"] = random.randrange(-10, 30)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 13:
                    new_planet["size"] = random.randrange(114,172)
                    new_planet["temperature"] = random.randrange(-50, -10)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 14:
                    new_planet["size"] = random.randrange(100,168)
                    new_planet["temperature"] = random.randrange(-90, -50)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 15:
                    new_planet["size"] = random.randrange(90,164)
                    new_planet["temperature"] = random.randrange(-130, -90)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                all_planets.append(new_planet)
            
        return all_planets

# %%
planets = create_new_planet(50)
planets
# Out:
# [{'size': 99, 'temperature': 255, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 143, 'temperature': 191, 'type': 'Gas giant', 'position': 2},
#  {'size': 158, 'temperature': 122, 'type': 'Gas giant', 'position': 3},
#  {'size': 151, 'temperature': 107, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 182, 'temperature': 70, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 227, 'temperature': 72, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 183, 'temperature': 43, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 192, 'temperature': 52, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 163, 'temperature': 30, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 160, 'temperature': 27, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 139, 'temperature': 5, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 164, 'temperature': 27, 'type': 'Forest planet', 'position': 12},
#  {'size': 118, 'temperature': -20, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 166, 'temperature': -52, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 124, 'temperature': -96, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 123, 'temperature': 244, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 165, 'temperature': 175, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 172, 'temperature': 159, 'type': 'Carbon planet', 'position': 3},
#  {'size': 168, 'temperature': 83, 'type': 'Helium planet', 'position': 4},
#  {'size': 208, 'temperature': 70, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 226, 'temperature': 82, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 242, 'temperature': 66, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 202, 'temperature': 39, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 162, 'temperature': 25, 'type': 'Carbon planet', 'position': 9},
#  {'size': 187, 'temperature': 36, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 156, 'temperature': 25, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 159, 'temperature': 0, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 134, 'temperature': -49, 'type': 'Carbon planet', 'position': 13},
#  {'size': 151, 'temperature': -85, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 154, 'temperature': -116, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 112, 'temperature': 258, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 151, 'temperature': 186, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 154, 'temperature': 134, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 159, 'temperature': 85, 'type': 'Forest planet', 'position': 4},
#  {'size': 165, 'temperature': 96, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 170, 'temperature': 89, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 198, 'temperature': 57, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 233, 'temperature': 32, 'type': 'Gas giant', 'position': 8},
#  {'size': 166, 'temperature': 59, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 164, 'temperature': 47, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 160, 'temperature': 37, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 185, 'temperature': 12, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 155, 'temperature': -27, 'type': 'Gas giant', 'position': 13},
#  {'size': 100, 'temperature': -80, 'type': 'Helium planet', 'position': 14},
#  {'size': 97, 'temperature': -92, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 109, 'temperature': 234, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 126, 'temperature': 208, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 129, 'temperature': 158, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 182, 'temperature': 76, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 187, 'temperature': 83, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 238, 'temperature': 88, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 243, 'temperature': 79, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 178, 'temperature': 50, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 165, 'temperature': 22, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 172, 'temperature': 21, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 139, 'temperature': 38, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 131, 'temperature': -9, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 147, 'temperature': -20, 'type': 'Carbon planet', 'position': 13},
#  {'size': 119, 'temperature': -89, 'type': 'Gas giant', 'position': 14},
#  {'size': 127,
#   'temperature': -116,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 96, 'temperature': 256, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 112, 'temperature': 175, 'type': 'Gas giant', 'position': 2},
#  {'size': 129, 'temperature': 135, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 187, 'temperature': 70, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 143, 'temperature': 75, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 204, 'temperature': 78, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 169, 'temperature': 58, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 171, 'temperature': 38, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 169, 'temperature': 32, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 197, 'temperature': 32, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 146, 'temperature': 31, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 175, 'temperature': 20, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 152, 'temperature': -15, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 143, 'temperature': -69, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 100, 'temperature': -102, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 160, 'temperature': 257, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 165, 'temperature': 170, 'type': 'Ammonia planet', 'position': 2},
#  {'size': 181, 'temperature': 131, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 185, 'temperature': 101, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 196, 'temperature': 96, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 230, 'temperature': 88, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 185, 'temperature': 50, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 169, 'temperature': 53, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 223, 'temperature': 35, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 225, 'temperature': 14, 'type': 'Gas giant', 'position': 10},
#  {'size': 168, 'temperature': 28, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 170, 'temperature': 7, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 161, 'temperature': -12, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 150, 'temperature': -60, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 103, 'temperature': -115, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 169, 'temperature': 229, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 155, 'temperature': 185, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 160, 'temperature': 141, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 194, 'temperature': 88, 'type': 'Ammonia planet', 'position': 4},
#  {'size': 160, 'temperature': 98, 'type': 'Forest planet', 'position': 5},
#  {'size': 161, 'temperature': 75, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 235, 'temperature': 56, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 208, 'temperature': 49, 'type': 'Ammonia planet', 'position': 8},
#  {'size': 186, 'temperature': 38, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 172, 'temperature': 20, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 201, 'temperature': 3, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 173, 'temperature': -8, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 131, 'temperature': -13, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 149, 'temperature': -63, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 158, 'temperature': -116, 'type': 'Gas giant', 'position': 15},
#  {'size': 168, 'temperature': 255, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 155, 'temperature': 202, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 179, 'temperature': 152, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 154, 'temperature': 102, 'type': 'Helium planet', 'position': 4},
#  {'size': 172, 'temperature': 94, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 198, 'temperature': 87, 'type': 'Helium planet', 'position': 6},
#  {'size': 238, 'temperature': 73, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 169, 'temperature': 66, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 176, 'temperature': 38, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 195, 'temperature': 19, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 147, 'temperature': 10, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 173, 'temperature': 27, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 127, 'temperature': -41, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 141, 'temperature': -55, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 128, 'temperature': -108, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 162, 'temperature': 257, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 113, 'temperature': 200, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 139, 'temperature': 129, 'type': 'Ammonia planet', 'position': 3},
#  {'size': 190, 'temperature': 92, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 180, 'temperature': 69, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 155, 'temperature': 81, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 207, 'temperature': 51, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 213, 'temperature': 60, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 166, 'temperature': 35, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 204, 'temperature': 15, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 183, 'temperature': 36, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 127, 'temperature': -6, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 122,
#   'temperature': -24,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 130, 'temperature': -88, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 163,
#   'temperature': -128,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 112, 'temperature': 242, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 161, 'temperature': 198, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 140, 'temperature': 145, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 155, 'temperature': 102, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 175, 'temperature': 99, 'type': 'Earth analog', 'position': 5},
#  {'size': 194, 'temperature': 89, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 226, 'temperature': 64, 'type': 'Helium planet', 'position': 7},
#  {'size': 199, 'temperature': 68, 'type': 'Forest planet', 'position': 8},
#  {'size': 177, 'temperature': 52, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 223, 'temperature': 45, 'type': 'Ocean planet', 'position': 10},
#  {'size': 187, 'temperature': 27, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 154, 'temperature': 0, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 148, 'temperature': -29, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 133, 'temperature': -84, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 145,
#   'temperature': -105,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 167, 'temperature': 255, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 116, 'temperature': 172, 'type': 'Earth analog', 'position': 2},
#  {'size': 114, 'temperature': 137, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 205, 'temperature': 93, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 196, 'temperature': 73, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 214, 'temperature': 75, 'type': 'Helium planet', 'position': 6},
#  {'size': 170, 'temperature': 63, 'type': 'Eccentric Jupiter', 'position': 7},
#  {'size': 229, 'temperature': 60, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 202, 'temperature': 22, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 203, 'temperature': 31, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 153, 'temperature': 25, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 160, 'temperature': 21, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 140, 'temperature': -18, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 129, 'temperature': -77, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 151, 'temperature': -107, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 94, 'temperature': 241, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 110, 'temperature': 177, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 125, 'temperature': 157, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 133, 'temperature': 101, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 136, 'temperature': 80, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 197, 'temperature': 70, 'type': 'Carbon planet', 'position': 6},
#  {'size': 199, 'temperature': 65, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 209, 'temperature': 30, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 203, 'temperature': 54, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 154, 'temperature': 12, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 173, 'temperature': 9, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 145, 'temperature': 22, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 126, 'temperature': -26, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 165, 'temperature': -54, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 100, 'temperature': -97, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 132, 'temperature': 230, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 144, 'temperature': 177, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 167, 'temperature': 127, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 195, 'temperature': 77, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 209, 'temperature': 77, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 216, 'temperature': 79, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 205, 'temperature': 48, 'type': 'Ammonia planet', 'position': 7},
#  {'size': 232, 'temperature': 33, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 191, 'temperature': 49, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 222, 'temperature': 18, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 207, 'temperature': 25, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 179, 'temperature': 15, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 166,
#   'temperature': -17,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 125, 'temperature': -54, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 123, 'temperature': -98, 'type': 'Chthonian planet', 'position': 15},
#  {'size': 117, 'temperature': 234, 'type': 'Gas giant', 'position': 1},
#  {'size': 128, 'temperature': 187, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 128, 'temperature': 126, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 160, 'temperature': 92, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 197, 'temperature': 88, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 217, 'temperature': 74, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 206, 'temperature': 42, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 221, 'temperature': 61, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 175, 'temperature': 43, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 174, 'temperature': 49, 'type': 'Gas giant', 'position': 10},
#  {'size': 163, 'temperature': 18, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 171, 'temperature': 19, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 165, 'temperature': -25, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 106, 'temperature': -78, 'type': 'Ammonia planet', 'position': 14},
#  {'size': 108, 'temperature': -97, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 160, 'temperature': 224, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 127, 'temperature': 194, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 148, 'temperature': 148, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 196, 'temperature': 98, 'type': 'Helium planet', 'position': 4},
#  {'size': 200, 'temperature': 88, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 177, 'temperature': 84, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 179, 'temperature': 50, 'type': 'Ammonia planet', 'position': 7},
#  {'size': 199, 'temperature': 69, 'type': 'Ammonia planet', 'position': 8},
#  {'size': 157, 'temperature': 30, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 226, 'temperature': 27, 'type': 'Gas giant', 'position': 10},
#  {'size': 181, 'temperature': 5, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 161, 'temperature': 14, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 135, 'temperature': -23, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 150, 'temperature': -76, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 140, 'temperature': -124, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 167, 'temperature': 259, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 169, 'temperature': 184, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 167, 'temperature': 144, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 136, 'temperature': 89, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 178, 'temperature': 95, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 212, 'temperature': 89, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 157, 'temperature': 68, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 175, 'temperature': 34, 'type': 'Helium planet', 'position': 8},
#  {'size': 210, 'temperature': 21, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 226, 'temperature': 43, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 148, 'temperature': 31, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 145, 'temperature': 19, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 162, 'temperature': -34, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 164, 'temperature': -83, 'type': 'Gas giant', 'position': 14},
#  {'size': 108, 'temperature': -108, 'type': 'Gas giant', 'position': 15},
#  {'size': 152, 'temperature': 254, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 126, 'temperature': 184, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 176, 'temperature': 140, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 164, 'temperature': 101, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 198, 'temperature': 80, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 166, 'temperature': 70, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 213, 'temperature': 58, 'type': 'Helium planet', 'position': 7},
#  {'size': 197, 'temperature': 61, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 176, 'temperature': 46, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 200, 'temperature': 36, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 168, 'temperature': 13, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 171, 'temperature': -5, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 114, 'temperature': -42, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 136,
#   'temperature': -64,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 103, 'temperature': -117, 'type': 'Gas giant', 'position': 15},
#  {'size': 114, 'temperature': 252, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 121, 'temperature': 174, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 141, 'temperature': 127, 'type': 'Helium planet', 'position': 3},
#  {'size': 184, 'temperature': 102, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 213, 'temperature': 60, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 219, 'temperature': 74, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 181, 'temperature': 66, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 177, 'temperature': 34, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 187, 'temperature': 50, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 177, 'temperature': 49, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 163, 'temperature': 9, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 125, 'temperature': -7, 'type': 'Ocean planet', 'position': 12},
#  {'size': 145,
#   'temperature': -40,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 150, 'temperature': -71, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 111, 'temperature': -94, 'type': 'Chthonian planet', 'position': 15},
#  {'size': 134, 'temperature': 250, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 163, 'temperature': 181, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 152, 'temperature': 158, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 153, 'temperature': 96, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 222, 'temperature': 61, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 162, 'temperature': 87, 'type': 'Gas giant', 'position': 6},
#  {'size': 239, 'temperature': 56, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 192, 'temperature': 30, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 167, 'temperature': 25, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 222, 'temperature': 16, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 187, 'temperature': 16, 'type': 'Gas giant', 'position': 11},
#  {'size': 171, 'temperature': 1, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 158, 'temperature': -22, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 159, 'temperature': -84, 'type': 'Gas giant', 'position': 14},
#  {'size': 110, 'temperature': -95, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 141, 'temperature': 249, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 139, 'temperature': 201, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 153, 'temperature': 136, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 150, 'temperature': 95, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 181, 'temperature': 83, 'type': 'Helium planet', 'position': 5},
#  {'size': 212, 'temperature': 78, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 196, 'temperature': 69, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 175, 'temperature': 52, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 223, 'temperature': 48, 'type': 'Helium planet', 'position': 9},
#  {'size': 142, 'temperature': 24, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 180, 'temperature': 5, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 126, 'temperature': 18, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 157, 'temperature': -43, 'type': 'Earth analog', 'position': 13},
#  {'size': 114, 'temperature': -72, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 138,
#   'temperature': -107,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 102, 'temperature': 259, 'type': 'Earth analog', 'position': 1},
#  {'size': 118, 'temperature': 186, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 148, 'temperature': 135, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 149, 'temperature': 109, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 203, 'temperature': 88, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 157, 'temperature': 82, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 210, 'temperature': 51, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 190, 'temperature': 42, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 222, 'temperature': 44, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 161, 'temperature': 41, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 143, 'temperature': 8, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 175, 'temperature': 4, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 159, 'temperature': -15, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 149, 'temperature': -51, 'type': 'Gas giant', 'position': 14},
#  {'size': 110, 'temperature': -122, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 119, 'temperature': 256, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 126, 'temperature': 190, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 177, 'temperature': 145, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 201, 'temperature': 84, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 217, 'temperature': 78, 'type': 'Helium planet', 'position': 5},
#  {'size': 194, 'temperature': 87, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 213, 'temperature': 66, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 184, 'temperature': 55, 'type': 'Helium planet', 'position': 8},
#  {'size': 153, 'temperature': 45, 'type': 'Gas giant', 'position': 9},
#  {'size': 153, 'temperature': 40, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 190, 'temperature': 4, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 140, 'temperature': 28, 'type': 'Helium planet', 'position': 12},
#  {'size': 153, 'temperature': -23, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 111, 'temperature': -76, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 127, 'temperature': -114, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 129, 'temperature': 227, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 150, 'temperature': 193, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 116, 'temperature': 149, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 139, 'temperature': 91, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 149, 'temperature': 64, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 182, 'temperature': 81, 'type': 'Gas giant', 'position': 6},
#  {'size': 174, 'temperature': 66, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 178, 'temperature': 57, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 172, 'temperature': 49, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 178, 'temperature': 14, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 207, 'temperature': 36, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 181, 'temperature': -8, 'type': 'Gas giant', 'position': 12},
#  {'size': 171, 'temperature': -16, 'type': 'Ocean planet', 'position': 13},
#  {'size': 136, 'temperature': -58, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 121, 'temperature': -109, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 138, 'temperature': 238, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 133, 'temperature': 187, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 118, 'temperature': 145, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 190, 'temperature': 107, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 179, 'temperature': 70, 'type': 'Earth analog', 'position': 5},
#  {'size': 189, 'temperature': 78, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 211, 'temperature': 71, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 198, 'temperature': 30, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 221, 'temperature': 21, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 229, 'temperature': 25, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 188, 'temperature': 7, 'type': 'Gas giant', 'position': 11},
#  {'size': 134, 'temperature': -1, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 164, 'temperature': -30, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 148, 'temperature': -57, 'type': 'Forest planet', 'position': 14},
#  {'size': 101, 'temperature': -102, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 157, 'temperature': 240, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 114, 'temperature': 184, 'type': 'Helium planet', 'position': 2},
#  {'size': 164, 'temperature': 128, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 192, 'temperature': 72, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 182, 'temperature': 94, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 162, 'temperature': 76, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 159, 'temperature': 75, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 188, 'temperature': 38, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 232, 'temperature': 42, 'type': 'Helium planet', 'position': 9},
#  {'size': 219, 'temperature': 40, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 193, 'temperature': 12, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 132, 'temperature': 9, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 119, 'temperature': -21, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 154, 'temperature': -89, 'type': 'Ammonia planet', 'position': 14},
#  {'size': 137, 'temperature': -108, 'type': 'Helium planet', 'position': 15},
#  {'size': 123, 'temperature': 237, 'type': 'Earth analog', 'position': 1},
#  {'size': 162, 'temperature': 201, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 147, 'temperature': 145, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 165, 'temperature': 108, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 146, 'temperature': 77, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 181, 'temperature': 85, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 183, 'temperature': 76, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 227, 'temperature': 38, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 241, 'temperature': 45, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 223, 'temperature': 24, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 184, 'temperature': 2, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 151, 'temperature': -2, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 152,
#   'temperature': -27,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 104, 'temperature': -79, 'type': 'Helium planet', 'position': 14},
#  {'size': 140,
#   'temperature': -102,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 133, 'temperature': 246, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 133, 'temperature': 190, 'type': 'Earth analog', 'position': 2},
#  {'size': 136, 'temperature': 141, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 159, 'temperature': 103, 'type': 'Helium planet', 'position': 4},
#  {'size': 231, 'temperature': 62, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 222, 'temperature': 81, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 168, 'temperature': 78, 'type': 'Earth analog', 'position': 7},
#  {'size': 202, 'temperature': 40, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 202, 'temperature': 51, 'type': 'Forest planet', 'position': 9},
#  {'size': 147, 'temperature': 15, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 205, 'temperature': 16, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 143, 'temperature': 7, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 149, 'temperature': -25, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 118, 'temperature': -67, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 97,
#   'temperature': -101,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 147, 'temperature': 224, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 172, 'temperature': 205, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 178, 'temperature': 125, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 189, 'temperature': 76, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 160, 'temperature': 88, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 153, 'temperature': 84, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 184, 'temperature': 45, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 237, 'temperature': 44, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 183, 'temperature': 54, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 172, 'temperature': 48, 'type': 'Earth analog', 'position': 10},
#  {'size': 179, 'temperature': 4, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 173, 'temperature': -1, 'type': 'Earth analog', 'position': 12},
#  {'size': 116,
#   'temperature': -40,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 160,
#   'temperature': -83,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 140,
#   'temperature': -94,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 125, 'temperature': 243, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 158, 'temperature': 183, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 166, 'temperature': 128, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 138, 'temperature': 99, 'type': 'Gas giant', 'position': 4},
#  {'size': 183, 'temperature': 78, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 230, 'temperature': 75, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 222, 'temperature': 55, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 166, 'temperature': 43, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 223, 'temperature': 56, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 172, 'temperature': 40, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 172, 'temperature': 19, 'type': 'Ammonia planet', 'position': 11},
#  {'size': 183, 'temperature': 25, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 142, 'temperature': -17, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 100, 'temperature': -62, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 97, 'temperature': -113, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 129, 'temperature': 229, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 118, 'temperature': 188, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 158, 'temperature': 146, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 185, 'temperature': 70, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 142, 'temperature': 72, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 194, 'temperature': 73, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 203, 'temperature': 50, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 185, 'temperature': 45, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 164, 'temperature': 44, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 208, 'temperature': 25, 'type': 'Gas giant', 'position': 10},
#  {'size': 149, 'temperature': 1, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 163, 'temperature': -2, 'type': 'Helium planet', 'position': 12},
#  {'size': 140, 'temperature': -38, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 150, 'temperature': -86, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 156, 'temperature': -101, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 122, 'temperature': 256, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 119, 'temperature': 178, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 168, 'temperature': 122, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 157, 'temperature': 75, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 223, 'temperature': 60, 'type': 'Forest planet', 'position': 5},
#  {'size': 228, 'temperature': 86, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 175, 'temperature': 64, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 161, 'temperature': 44, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 194, 'temperature': 20, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 168, 'temperature': 24, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 141, 'temperature': 23, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 158, 'temperature': 21, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 117, 'temperature': -26, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 150, 'temperature': -53, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 160, 'temperature': -102, 'type': 'Helium planet', 'position': 15},
#  {'size': 170, 'temperature': 230, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 159, 'temperature': 209, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 170, 'temperature': 158, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 137, 'temperature': 102, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 145, 'temperature': 91, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 225, 'temperature': 85, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 239, 'temperature': 74, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 179, 'temperature': 48, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 173, 'temperature': 44, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 197, 'temperature': 24, 'type': 'Gas giant', 'position': 10},
#  {'size': 180, 'temperature': 0, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 145, 'temperature': -1, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 121, 'temperature': -31, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 154, 'temperature': -58, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 100, 'temperature': -111, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 156, 'temperature': 224, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 149, 'temperature': 193, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 126, 'temperature': 148, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 167, 'temperature': 71, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 201, 'temperature': 78, 'type': 'Helium planet', 'position': 5},
#  {'size': 236, 'temperature': 78, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 222, 'temperature': 75, 'type': 'Helium planet', 'position': 7},
#  {'size': 172, 'temperature': 56, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 205, 'temperature': 51, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 217, 'temperature': 41, 'type': 'Helium planet', 'position': 10},
#  {'size': 156, 'temperature': 33, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 179, 'temperature': -3, 'type': 'Helium planet', 'position': 12},
#  {'size': 158, 'temperature': -32, 'type': 'Earth analog', 'position': 13},
#  {'size': 145, 'temperature': -68, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 135, 'temperature': -111, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 112, 'temperature': 244, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 143, 'temperature': 176, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 139, 'temperature': 144, 'type': 'Helium planet', 'position': 3},
#  {'size': 124, 'temperature': 82, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 199, 'temperature': 81, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 174, 'temperature': 84, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 240, 'temperature': 40, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 178, 'temperature': 54, 'type': 'Gas giant', 'position': 8},
#  {'size': 191, 'temperature': 53, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 152, 'temperature': 30, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 144, 'temperature': 7, 'type': 'Gas giant', 'position': 11},
#  {'size': 150, 'temperature': 15, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 149, 'temperature': -41, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 127, 'temperature': -70, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 106, 'temperature': -99, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 115, 'temperature': 258, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 122, 'temperature': 196, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 175, 'temperature': 147, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 156, 'temperature': 106, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 156, 'temperature': 96, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 212, 'temperature': 82, 'type': 'Ocean planet', 'position': 6},
#  {'size': 156, 'temperature': 71, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 197, 'temperature': 48, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 173, 'temperature': 31, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 179, 'temperature': 24, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 185, 'temperature': 26, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 174, 'temperature': 0, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 141, 'temperature': -49, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 121, 'temperature': -56, 'type': 'Helium planet', 'position': 14},
#  {'size': 94, 'temperature': -122, 'type': 'Helium planet', 'position': 15},
#  {'size': 169, 'temperature': 231, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 136, 'temperature': 176, 'type': 'Helium planet', 'position': 2},
#  {'size': 181, 'temperature': 150, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 121, 'temperature': 70, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 150, 'temperature': 81, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 228, 'temperature': 73, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 213, 'temperature': 78, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 237, 'temperature': 52, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 217, 'temperature': 48, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 204, 'temperature': 14, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 144, 'temperature': 14, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 183, 'temperature': 12, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 131, 'temperature': -19, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 118, 'temperature': -52, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 90, 'temperature': -122, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 160, 'temperature': 242, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 167, 'temperature': 180, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 136, 'temperature': 120, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 132, 'temperature': 89, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 228, 'temperature': 99, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 159, 'temperature': 89, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 245, 'temperature': 47, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 183, 'temperature': 54, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 153, 'temperature': 34, 'type': 'Ammonia planet', 'position': 9},
#  {'size': 157, 'temperature': 29, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 157, 'temperature': 25, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 169, 'temperature': 8, 'type': 'Carbon planet', 'position': 12},
#  {'size': 130, 'temperature': -39, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 142, 'temperature': -76, 'type': 'Ammonia planet', 'position': 14},
#  {'size': 137,
#   'temperature': -130,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 139, 'temperature': 227, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 128, 'temperature': 185, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 152, 'temperature': 122, 'type': 'Gas giant', 'position': 3},
#  {'size': 144, 'temperature': 97, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 231, 'temperature': 79, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 208, 'temperature': 70, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 226, 'temperature': 45, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 202, 'temperature': 54, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 164, 'temperature': 21, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 196, 'temperature': 27, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 142, 'temperature': 9, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 183, 'temperature': -9, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 141, 'temperature': -14, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 112, 'temperature': -57, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 153, 'temperature': -108, 'type': 'Helium planet', 'position': 15},
#  {'size': 109, 'temperature': 258, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 109, 'temperature': 172, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 148, 'temperature': 145, 'type': 'Ammonia planet', 'position': 3},
#  {'size': 145, 'temperature': 82, 'type': 'Earth analog', 'position': 4},
#  {'size': 178, 'temperature': 97, 'type': 'Earth analog', 'position': 5},
#  {'size': 217, 'temperature': 83, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 188, 'temperature': 57, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 233, 'temperature': 64, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 173, 'temperature': 31, 'type': 'Gas giant', 'position': 9},
#  {'size': 198, 'temperature': 25, 'type': 'Gas giant', 'position': 10},
#  {'size': 157, 'temperature': 8, 'type': 'Helium planet', 'position': 11},
#  {'size': 163, 'temperature': 27, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 123, 'temperature': -47, 'type': 'Helium planet', 'position': 13},
#  {'size': 149, 'temperature': -72, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 117,
#   'temperature': -114,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 104, 'temperature': 227, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 150, 'temperature': 193, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 149, 'temperature': 120, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 184, 'temperature': 91, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 171, 'temperature': 67, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 204, 'temperature': 86, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 241, 'temperature': 55, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 156, 'temperature': 42, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 219, 'temperature': 32, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 224, 'temperature': 37, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 197, 'temperature': 10, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 148, 'temperature': -4, 'type': 'Helium planet', 'position': 12},
#  {'size': 159, 'temperature': -34, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 161, 'temperature': -63, 'type': 'Earth analog', 'position': 14},
#  {'size': 105,
#   'temperature': -114,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 165, 'temperature': 229, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 151, 'temperature': 201, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 144, 'temperature': 154, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 157, 'temperature': 87, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 190, 'temperature': 64, 'type': 'Gas giant', 'position': 5},
#  {'size': 171, 'temperature': 78, 'type': 'Helium planet', 'position': 6},
#  {'size': 245, 'temperature': 49, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 231, 'temperature': 35, 'type': 'Forest planet', 'position': 8},
#  {'size': 152, 'temperature': 33, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 171, 'temperature': 26, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 203, 'temperature': 27, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 162, 'temperature': 29, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 130, 'temperature': -26, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 133, 'temperature': -78, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 162, 'temperature': -107, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 106, 'temperature': 248, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 159, 'temperature': 170, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 150, 'temperature': 131, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 197, 'temperature': 95, 'type': 'Helium planet', 'position': 4},
#  {'size': 175, 'temperature': 66, 'type': 'Gas giant', 'position': 5},
#  {'size': 153, 'temperature': 76, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 223, 'temperature': 77, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 157, 'temperature': 53, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 243, 'temperature': 46, 'type': 'Helium planet', 'position': 9},
#  {'size': 175, 'temperature': 29, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 206, 'temperature': 24, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 179, 'temperature': 8, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 154, 'temperature': -24, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 113, 'temperature': -59, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 107, 'temperature': -94, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 120, 'temperature': 228, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 138, 'temperature': 194, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 145, 'temperature': 143, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 161, 'temperature': 88, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 136, 'temperature': 77, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 155, 'temperature': 75, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 245, 'temperature': 55, 'type': 'Helium planet', 'position': 7},
#  {'size': 158, 'temperature': 67, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 150, 'temperature': 26, 'type': 'Gas giant', 'position': 9},
#  {'size': 170, 'temperature': 30, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 143, 'temperature': 13, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 147, 'temperature': 28, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 135, 'temperature': -47, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 144,
#   'temperature': -59,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 92, 'temperature': -122, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 130, 'temperature': 227, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 109, 'temperature': 199, 'type': 'Earth analog', 'position': 2},
#  {'size': 138, 'temperature': 135, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 141, 'temperature': 86, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 161, 'temperature': 71, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 204, 'temperature': 86, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 233, 'temperature': 55, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 172, 'temperature': 66, 'type': 'Earth analog', 'position': 8},
#  {'size': 176, 'temperature': 23, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 190, 'temperature': 37, 'type': 'Helium planet', 'position': 10},
#  {'size': 188, 'temperature': 1, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 125, 'temperature': 1, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 157,
#   'temperature': -32,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 111, 'temperature': -90, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 90, 'temperature': -112, 'type': 'Chthonian planet', 'position': 15},
#  {'size': 156, 'temperature': 242, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 152, 'temperature': 189, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 119, 'temperature': 145, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 118, 'temperature': 100, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 191, 'temperature': 88, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 147, 'temperature': 73, 'type': 'Carbon planet', 'position': 6},
#  {'size': 200, 'temperature': 72, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 207, 'temperature': 34, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 158, 'temperature': 59, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 213, 'temperature': 39, 'type': 'Gas giant', 'position': 10},
#  {'size': 173, 'temperature': 31, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 139, 'temperature': 6, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 153,
#   'temperature': -38,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 167, 'temperature': -70, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 163,
#   'temperature': -103,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 168, 'temperature': 256, 'type': 'Gas giant', 'position': 1},
#  {'size': 155, 'temperature': 199, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 154, 'temperature': 140, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 120, 'temperature': 96, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 179, 'temperature': 95, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 212, 'temperature': 83, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 185, 'temperature': 62, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 190, 'temperature': 31, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 168, 'temperature': 54, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 172, 'temperature': 48, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 165, 'temperature': 25, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 144, 'temperature': -9, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 115, 'temperature': -18, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 144, 'temperature': -51, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 106,
#   'temperature': -117,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 95, 'temperature': 232, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 172, 'temperature': 204, 'type': 'Forest planet', 'position': 2},
#  {'size': 166, 'temperature': 151, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 134, 'temperature': 91, 'type': 'Helium planet', 'position': 4},
#  {'size': 203, 'temperature': 95, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 183, 'temperature': 81, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 224, 'temperature': 51, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 226, 'temperature': 30, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 194, 'temperature': 23, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 160, 'temperature': 48, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 156, 'temperature': 19, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 176, 'temperature': -9, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 167,
#   'temperature': -16,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 156, 'temperature': -80, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 130, 'temperature': -115, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 141, 'temperature': 259, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 112, 'temperature': 198, 'type': 'Helium planet', 'position': 2},
#  {'size': 120, 'temperature': 152, 'type': 'Gas giant', 'position': 3},
#  {'size': 202, 'temperature': 78, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 206, 'temperature': 65, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 192, 'temperature': 71, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 209, 'temperature': 40, 'type': 'Helium planet', 'position': 7},
#  {'size': 172, 'temperature': 66, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 214, 'temperature': 33, 'type': 'Gas giant', 'position': 9},
#  {'size': 225, 'temperature': 48, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 157, 'temperature': 25, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 180, 'temperature': 8, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 128, 'temperature': -39, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 102, 'temperature': -53, 'type': 'Helium planet', 'position': 14},
#  {'size': 103, 'temperature': -101, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 140, 'temperature': 225, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 171, 'temperature': 190, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 144, 'temperature': 137, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 193, 'temperature': 70, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 228, 'temperature': 75, 'type': 'Helium planet', 'position': 5},
#  {'size': 235, 'temperature': 89, 'type': 'Helium planet', 'position': 6},
#  {'size': 228, 'temperature': 58, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 220, 'temperature': 35, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 244, 'temperature': 22, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 181, 'temperature': 25, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 165, 'temperature': 1, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 172, 'temperature': 28, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 143, 'temperature': -14, 'type': 'Gas giant', 'position': 13},
#  {'size': 112, 'temperature': -57, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 114, 'temperature': -118, 'type': 'Ammonia planet', 'position': 15},
#  {'size': 98, 'temperature': 238, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 131, 'temperature': 206, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 155, 'temperature': 140, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 156, 'temperature': 74, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 199, 'temperature': 96, 'type': 'Forest planet', 'position': 5},
#  {'size': 166, 'temperature': 73, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 241, 'temperature': 76, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 231, 'temperature': 39, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 228, 'temperature': 26, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 194, 'temperature': 35, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 157, 'temperature': 19, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 127, 'temperature': 17, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 133, 'temperature': -28, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 130, 'temperature': -69, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 154, 'temperature': -103, 'type': 'Brown dwarf', 'position': 15}]

# %%
len(planets)
# Out:
# 750

# %%
planets[1]
# Out:
# {'size': 143, 'temperature': 191, 'type': 'Gas giant', 'position': 2}

# %%
def all_unique(all_planets):
    seen = list()
    return not any(i in seen or seen.append(i) for i in all_planets)

# %%
print("Are all images unique?", all_unique(planets))
# Add token Id to each image
i = 1
for item in planets:
    item["tokenId"] = i
    i = i + 1
   
print(all_planets)
# Out:
# Are all images unique? True
# []

# %%
os.mkdir(f'./metadata')

METADATA_FILE_NAME = './metadata/all-traits.json'; 
with open(METADATA_FILE_NAME, 'w') as outfile:
    json.dump(planets, outfile, indent=4)

# %%
#### Generate Metadata for each Image    

f = open('./metadata/all-traits.json',) 
data = json.load(f)

# Changes this IMAGES_BASE_URL to yours 
IMAGES_BASE_URL = "ipfs/QmbgeJoPQ7AtBDarKUnrMDt1r6CNw41FzML7ZPXzE5W27Z/"
PROJECT_NAME = "NFT_OGM"

def getAttribute(key, value):
    return {
        "trait_type": key,
        "value": value
    }
for i in data:
    token_id = i['tokenId']
    token = {
        "image": IMAGES_BASE_URL + str(token_id%15) + '.png',
        "tokenId": token_id,
        "name": PROJECT_NAME + ' #' + str(token_id),
        "attributes": []
    }
    token["attributes"].append(getAttribute("size", i["size"]))
    token["attributes"].append(getAttribute("temperature", i["temperature"]))
    token["attributes"].append(getAttribute("type", i["type"]))
    token["attributes"].append(getAttribute("position", i["position"]))

    with open('./metadata/' + str(token_id) + ".json", 'w') as outfile:
        json.dump(token, outfile, indent=4)
f.close()
