# %%
import random
import json
import os

# %%
types = ['Brown dwarf', 'Chthonian planet', 'Eccentric Jupiter', 'Gas giant', 'Helium planet', 'Ammonia planet', 'Carbon planet',
       'Earth analog', 'Forest planet', 'Ocean planet']
pweights = [52.5, 20, 10, 5, 4, 3, 2, 2, 1, 0.5]

# %%
sum(pweights)
# Out:
# 100.0

# %%
all_planets = []

# %%
def create_new_planet(n):
        all_planets = []
        for j in range(n):
            for i in range(1,16):
                new_planet = {}
                if i == 1:
                    new_planet["size"] = random.randrange(94,172)
                    new_planet["temperature"] = random.randrange(220, 260)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 2:
                    new_planet["size"] = random.randrange(104,176)
                    new_planet["temperature"] = random.randrange(170, 210)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 3:
                    new_planet["size"] = random.randrange(112,182)
                    new_planet["temperature"] = random.randrange(120, 160)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 4:
                    new_planet["size"] = random.randrange(118,208)
                    new_planet["temperature"] = random.randrange(70, 110)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 5:
                    new_planet["size"] = random.randrange(133,232)
                    new_planet["temperature"] = random.randrange(60, 100)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 6:
                    new_planet["size"] = random.randrange(146,242)
                    new_planet["temperature"] = random.randrange(70, 90)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 7:
                    new_planet["size"] = random.randrange(152,248)
                    new_planet["temperature"] = random.randrange(40, 80)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 8:
                    new_planet["size"] = random.randrange(156,242)
                    new_planet["temperature"] = random.randrange(30, 70)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 9:
                    new_planet["size"] = random.randrange(150,246)
                    new_planet["temperature"] = random.randrange(20,60)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 10:
                    new_planet["size"] = random.randrange(142,232)
                    new_planet["temperature"] = random.randrange(10, 50)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 11:
                    new_planet["size"] = random.randrange(136,210)
                    new_planet["temperature"] = random.randrange(0, 40)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 12:
                    new_planet["size"] = random.randrange(125,186)
                    new_planet["temperature"] = random.randrange(-10, 30)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 13:
                    new_planet["size"] = random.randrange(114,172)
                    new_planet["temperature"] = random.randrange(-50, -10)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 14:
                    new_planet["size"] = random.randrange(100,168)
                    new_planet["temperature"] = random.randrange(-90, -50)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                elif i == 15:
                    new_planet["size"] = random.randrange(90,164)
                    new_planet["temperature"] = random.randrange(-130, -90)
                    new_planet["type"] = random.choices(types, weights = pweights)[0]
                    new_planet["position"] = i
                all_planets.append(new_planet)
            
        return all_planets

# %%
planets = create_new_planet(50)
planets
# Out:
# [{'size': 118, 'temperature': 248, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 174, 'temperature': 180, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 131, 'temperature': 131, 'type': 'Ammonia planet', 'position': 3},
#  {'size': 181, 'temperature': 77, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 217, 'temperature': 89, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 185, 'temperature': 73, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 246, 'temperature': 73, 'type': 'Eccentric Jupiter', 'position': 7},
#  {'size': 163, 'temperature': 38, 'type': 'Earth analog', 'position': 8},
#  {'size': 189, 'temperature': 50, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 204, 'temperature': 46, 'type': 'Helium planet', 'position': 10},
#  {'size': 159, 'temperature': 6, 'type': 'Gas giant', 'position': 11},
#  {'size': 172, 'temperature': 17, 'type': 'Gas giant', 'position': 12},
#  {'size': 144, 'temperature': -20, 'type': 'Ocean planet', 'position': 13},
#  {'size': 134, 'temperature': -59, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 105,
#   'temperature': -107,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 118, 'temperature': 248, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 125, 'temperature': 193, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 148, 'temperature': 155, 'type': 'Forest planet', 'position': 3},
#  {'size': 124, 'temperature': 70, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 150, 'temperature': 84, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 168, 'temperature': 83, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 176, 'temperature': 44, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 172, 'temperature': 51, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 202, 'temperature': 36, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 185, 'temperature': 24, 'type': 'Ocean planet', 'position': 10},
#  {'size': 184, 'temperature': 17, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 157, 'temperature': 23, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 127, 'temperature': -46, 'type': 'Ammonia planet', 'position': 13},
#  {'size': 127, 'temperature': -72, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 158, 'temperature': -116, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 169, 'temperature': 251, 'type': 'Gas giant', 'position': 1},
#  {'size': 128, 'temperature': 174, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 180, 'temperature': 130, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 128, 'temperature': 87, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 206, 'temperature': 74, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 239, 'temperature': 82, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 190, 'temperature': 66, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 241, 'temperature': 49, 'type': 'Ammonia planet', 'position': 8},
#  {'size': 233, 'temperature': 34, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 171, 'temperature': 41, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 143, 'temperature': 13, 'type': 'Gas giant', 'position': 11},
#  {'size': 139, 'temperature': -8, 'type': 'Gas giant', 'position': 12},
#  {'size': 117, 'temperature': -13, 'type': 'Gas giant', 'position': 13},
#  {'size': 114, 'temperature': -76, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 150,
#   'temperature': -103,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 150, 'temperature': 251, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 149, 'temperature': 197, 'type': 'Gas giant', 'position': 2},
#  {'size': 144, 'temperature': 123, 'type': 'Gas giant', 'position': 3},
#  {'size': 183, 'temperature': 77, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 206, 'temperature': 85, 'type': 'Carbon planet', 'position': 5},
#  {'size': 153, 'temperature': 79, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 187, 'temperature': 44, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 229, 'temperature': 50, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 212, 'temperature': 31, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 174, 'temperature': 49, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 191, 'temperature': 37, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 168, 'temperature': 29, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 139, 'temperature': -50, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 138, 'temperature': -52, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 104, 'temperature': -107, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 94, 'temperature': 244, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 166, 'temperature': 185, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 120, 'temperature': 137, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 136, 'temperature': 106, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 195, 'temperature': 92, 'type': 'Gas giant', 'position': 5},
#  {'size': 212, 'temperature': 72, 'type': 'Ammonia planet', 'position': 6},
#  {'size': 238, 'temperature': 57, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 223, 'temperature': 57, 'type': 'Earth analog', 'position': 8},
#  {'size': 228, 'temperature': 57, 'type': 'Gas giant', 'position': 9},
#  {'size': 225, 'temperature': 17, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 170, 'temperature': 30, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 181, 'temperature': 8, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 170, 'temperature': -32, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 151,
#   'temperature': -55,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 114, 'temperature': -120, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 171, 'temperature': 221, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 141, 'temperature': 197, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 180, 'temperature': 150, 'type': 'Gas giant', 'position': 3},
#  {'size': 205, 'temperature': 81, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 159, 'temperature': 81, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 188, 'temperature': 86, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 241, 'temperature': 40, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 163, 'temperature': 40, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 181, 'temperature': 51, 'type': 'Carbon planet', 'position': 9},
#  {'size': 145, 'temperature': 28, 'type': 'Gas giant', 'position': 10},
#  {'size': 155, 'temperature': 18, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 162, 'temperature': 10, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 146, 'temperature': -28, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 141,
#   'temperature': -88,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 98, 'temperature': -94, 'type': 'Eccentric Jupiter', 'position': 15},
#  {'size': 154, 'temperature': 220, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 154, 'temperature': 170, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 132, 'temperature': 126, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 184, 'temperature': 80, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 161, 'temperature': 68, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 207, 'temperature': 75, 'type': 'Ammonia planet', 'position': 6},
#  {'size': 153, 'temperature': 58, 'type': 'Helium planet', 'position': 7},
#  {'size': 208, 'temperature': 30, 'type': 'Ammonia planet', 'position': 8},
#  {'size': 210, 'temperature': 38, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 144, 'temperature': 31, 'type': 'Gas giant', 'position': 10},
#  {'size': 176, 'temperature': 23, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 130, 'temperature': 17, 'type': 'Ammonia planet', 'position': 12},
#  {'size': 114, 'temperature': -14, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 119, 'temperature': -64, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 148, 'temperature': -124, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 129, 'temperature': 223, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 152, 'temperature': 171, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 180, 'temperature': 130, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 207, 'temperature': 94, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 143, 'temperature': 74, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 161, 'temperature': 81, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 161, 'temperature': 78, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 201, 'temperature': 62, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 169, 'temperature': 55, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 205, 'temperature': 17, 'type': 'Gas giant', 'position': 10},
#  {'size': 198, 'temperature': 19, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 148, 'temperature': 25, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 117,
#   'temperature': -11,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 128, 'temperature': -57, 'type': 'Gas giant', 'position': 14},
#  {'size': 105, 'temperature': -106, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 114, 'temperature': 254, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 158, 'temperature': 196, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 130, 'temperature': 143, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 145, 'temperature': 96, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 229, 'temperature': 61, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 187, 'temperature': 84, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 189, 'temperature': 53, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 173, 'temperature': 47, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 227, 'temperature': 33, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 180, 'temperature': 18, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 198, 'temperature': 10, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 140, 'temperature': 11, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 129, 'temperature': -43, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 121, 'temperature': -85, 'type': 'Ammonia planet', 'position': 14},
#  {'size': 132,
#   'temperature': -109,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 158, 'temperature': 248, 'type': 'Ammonia planet', 'position': 1},
#  {'size': 128, 'temperature': 177, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 148, 'temperature': 126, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 144, 'temperature': 70, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 140, 'temperature': 99, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 182, 'temperature': 89, 'type': 'Gas giant', 'position': 6},
#  {'size': 163, 'temperature': 42, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 235, 'temperature': 60, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 179, 'temperature': 42, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 217, 'temperature': 18, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 167, 'temperature': 9, 'type': 'Carbon planet', 'position': 11},
#  {'size': 152, 'temperature': 0, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 147, 'temperature': -32, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 144, 'temperature': -81, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 114, 'temperature': -102, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 171, 'temperature': 245, 'type': 'Earth analog', 'position': 1},
#  {'size': 128, 'temperature': 183, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 117, 'temperature': 156, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 138, 'temperature': 97, 'type': 'Earth analog', 'position': 4},
#  {'size': 214, 'temperature': 61, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 236, 'temperature': 70, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 227, 'temperature': 79, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 174, 'temperature': 56, 'type': 'Forest planet', 'position': 8},
#  {'size': 234, 'temperature': 42, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 212, 'temperature': 48, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 174, 'temperature': 26, 'type': 'Earth analog', 'position': 11},
#  {'size': 174, 'temperature': 24, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 159, 'temperature': -36, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 118, 'temperature': -70, 'type': 'Helium planet', 'position': 14},
#  {'size': 96, 'temperature': -107, 'type': 'Chthonian planet', 'position': 15},
#  {'size': 122, 'temperature': 230, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 141, 'temperature': 197, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 168, 'temperature': 123, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 134, 'temperature': 93, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 159, 'temperature': 87, 'type': 'Forest planet', 'position': 5},
#  {'size': 178, 'temperature': 75, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 189, 'temperature': 48, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 160, 'temperature': 44, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 153, 'temperature': 42, 'type': 'Ammonia planet', 'position': 9},
#  {'size': 177, 'temperature': 31, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 197, 'temperature': 29, 'type': 'Gas giant', 'position': 11},
#  {'size': 141, 'temperature': 12, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 170, 'temperature': -36, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 118, 'temperature': -90, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 125, 'temperature': -110, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 136, 'temperature': 254, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 142, 'temperature': 192, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 143, 'temperature': 146, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 131, 'temperature': 73, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 182, 'temperature': 99, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 226, 'temperature': 85, 'type': 'Forest planet', 'position': 6},
#  {'size': 224, 'temperature': 73, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 231, 'temperature': 54, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 206, 'temperature': 55, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 183, 'temperature': 45, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 167, 'temperature': 36, 'type': 'Helium planet', 'position': 11},
#  {'size': 183, 'temperature': 23, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 154, 'temperature': -41, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 145, 'temperature': -54, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 104, 'temperature': -91, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 123, 'temperature': 222, 'type': 'Helium planet', 'position': 1},
#  {'size': 128, 'temperature': 187, 'type': 'Carbon planet', 'position': 2},
#  {'size': 145, 'temperature': 139, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 196, 'temperature': 79, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 212, 'temperature': 79, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 157, 'temperature': 83, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 199, 'temperature': 55, 'type': 'Gas giant', 'position': 7},
#  {'size': 183, 'temperature': 59, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 179, 'temperature': 36, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 208, 'temperature': 30, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 136, 'temperature': 23, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 147, 'temperature': -3, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 142, 'temperature': -20, 'type': 'Gas giant', 'position': 13},
#  {'size': 131, 'temperature': -72, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 153,
#   'temperature': -94,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 103, 'temperature': 245, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 161, 'temperature': 192, 'type': 'Gas giant', 'position': 2},
#  {'size': 170, 'temperature': 149, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 187, 'temperature': 74, 'type': 'Forest planet', 'position': 4},
#  {'size': 140, 'temperature': 95, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 185, 'temperature': 87, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 152, 'temperature': 45, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 192, 'temperature': 38, 'type': 'Helium planet', 'position': 8},
#  {'size': 152, 'temperature': 45, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 190, 'temperature': 41, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 155, 'temperature': 26, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 167, 'temperature': 12, 'type': 'Carbon planet', 'position': 12},
#  {'size': 143, 'temperature': -42, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 138, 'temperature': -88, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 97, 'temperature': -126, 'type': 'Earth analog', 'position': 15},
#  {'size': 107, 'temperature': 230, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 119, 'temperature': 189, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 145, 'temperature': 129, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 131, 'temperature': 88, 'type': 'Ammonia planet', 'position': 4},
#  {'size': 180, 'temperature': 93, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 189, 'temperature': 74, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 237, 'temperature': 54, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 231, 'temperature': 43, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 206, 'temperature': 57, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 192, 'temperature': 32, 'type': 'Carbon planet', 'position': 10},
#  {'size': 140, 'temperature': 4, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 162, 'temperature': 20, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 165, 'temperature': -43, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 164, 'temperature': -69, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 121, 'temperature': -100, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 94, 'temperature': 229, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 150, 'temperature': 206, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 131, 'temperature': 133, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 197, 'temperature': 99, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 187, 'temperature': 96, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 237, 'temperature': 86, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 234, 'temperature': 48, 'type': 'Ammonia planet', 'position': 7},
#  {'size': 190, 'temperature': 31, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 199, 'temperature': 47, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 209, 'temperature': 13, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 141, 'temperature': 23, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 133, 'temperature': 24, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 119, 'temperature': -32, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 155,
#   'temperature': -71,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 108, 'temperature': -120, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 116, 'temperature': 251, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 142, 'temperature': 206, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 170, 'temperature': 150, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 199, 'temperature': 81, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 161, 'temperature': 82, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 215, 'temperature': 85, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 214, 'temperature': 47, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 177, 'temperature': 64, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 192, 'temperature': 33, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 230, 'temperature': 43, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 194, 'temperature': 18, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 173, 'temperature': 24, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 141, 'temperature': -33, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 131, 'temperature': -83, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 93, 'temperature': -112, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 152, 'temperature': 255, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 112, 'temperature': 174, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 167, 'temperature': 158, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 140, 'temperature': 73, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 188, 'temperature': 68, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 195, 'temperature': 87, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 179, 'temperature': 64, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 215, 'temperature': 65, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 216, 'temperature': 47, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 147, 'temperature': 12, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 149, 'temperature': 34, 'type': 'Earth analog', 'position': 11},
#  {'size': 149, 'temperature': 0, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 137, 'temperature': -15, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 148, 'temperature': -70, 'type': 'Gas giant', 'position': 14},
#  {'size': 100, 'temperature': -105, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 105, 'temperature': 236, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 149, 'temperature': 170, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 162, 'temperature': 157, 'type': 'Helium planet', 'position': 3},
#  {'size': 120, 'temperature': 86, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 211, 'temperature': 74, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 199, 'temperature': 80, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 178, 'temperature': 43, 'type': 'Gas giant', 'position': 7},
#  {'size': 227, 'temperature': 46, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 154, 'temperature': 59, 'type': 'Gas giant', 'position': 9},
#  {'size': 180, 'temperature': 20, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 176, 'temperature': 1, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 174, 'temperature': -8, 'type': 'Helium planet', 'position': 12},
#  {'size': 149, 'temperature': -38, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 111, 'temperature': -78, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 126, 'temperature': -98, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 144, 'temperature': 255, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 129, 'temperature': 185, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 119, 'temperature': 152, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 167, 'temperature': 85, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 182, 'temperature': 80, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 148, 'temperature': 73, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 217, 'temperature': 50, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 189, 'temperature': 45, 'type': 'Carbon planet', 'position': 8},
#  {'size': 150, 'temperature': 42, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 159, 'temperature': 19, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 163, 'temperature': 12, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 153, 'temperature': 20, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 138, 'temperature': -42, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 128, 'temperature': -84, 'type': 'Gas giant', 'position': 14},
#  {'size': 92, 'temperature': -127, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 140, 'temperature': 229, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 165, 'temperature': 179, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 126, 'temperature': 145, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 183, 'temperature': 96, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 203, 'temperature': 70, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 185, 'temperature': 84, 'type': 'Ammonia planet', 'position': 6},
#  {'size': 198, 'temperature': 53, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 222, 'temperature': 67, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 244, 'temperature': 50, 'type': 'Ammonia planet', 'position': 9},
#  {'size': 180, 'temperature': 48, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 136, 'temperature': 32, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 178, 'temperature': 1, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 171, 'temperature': -17, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 163, 'temperature': -67, 'type': 'Carbon planet', 'position': 14},
#  {'size': 140,
#   'temperature': -112,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 110, 'temperature': 233, 'type': 'Gas giant', 'position': 1},
#  {'size': 171, 'temperature': 206, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 137, 'temperature': 148, 'type': 'Carbon planet', 'position': 3},
#  {'size': 170, 'temperature': 85, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 196, 'temperature': 99, 'type': 'Gas giant', 'position': 5},
#  {'size': 231, 'temperature': 75, 'type': 'Ammonia planet', 'position': 6},
#  {'size': 159, 'temperature': 52, 'type': 'Eccentric Jupiter', 'position': 7},
#  {'size': 241, 'temperature': 48, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 223, 'temperature': 35, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 167, 'temperature': 42, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 138, 'temperature': 8, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 132, 'temperature': 19, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 161, 'temperature': -17, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 160, 'temperature': -72, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 161,
#   'temperature': -105,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 144, 'temperature': 233, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 113, 'temperature': 197, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 157, 'temperature': 147, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 156, 'temperature': 78, 'type': 'Gas giant', 'position': 4},
#  {'size': 157, 'temperature': 87, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 208, 'temperature': 86, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 157, 'temperature': 43, 'type': 'Eccentric Jupiter', 'position': 7},
#  {'size': 197, 'temperature': 64, 'type': 'Earth analog', 'position': 8},
#  {'size': 169, 'temperature': 55, 'type': 'Helium planet', 'position': 9},
#  {'size': 190, 'temperature': 12, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 165, 'temperature': 29, 'type': 'Gas giant', 'position': 11},
#  {'size': 176, 'temperature': 28, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 130, 'temperature': -42, 'type': 'Helium planet', 'position': 13},
#  {'size': 167, 'temperature': -59, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 102,
#   'temperature': -100,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 150, 'temperature': 256, 'type': 'Carbon planet', 'position': 1},
#  {'size': 165, 'temperature': 208, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 165, 'temperature': 147, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 139, 'temperature': 84, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 228, 'temperature': 71, 'type': 'Helium planet', 'position': 5},
#  {'size': 240, 'temperature': 83, 'type': 'Gas giant', 'position': 6},
#  {'size': 222, 'temperature': 66, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 168, 'temperature': 58, 'type': 'Gas giant', 'position': 8},
#  {'size': 152, 'temperature': 38, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 197, 'temperature': 12, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 205, 'temperature': 14, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 160, 'temperature': -2, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 121,
#   'temperature': -14,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 153, 'temperature': -80, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 134, 'temperature': -97, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 151, 'temperature': 233, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 175, 'temperature': 181, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 114, 'temperature': 151, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 151, 'temperature': 109, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 205, 'temperature': 72, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 152, 'temperature': 74, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 220, 'temperature': 45, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 215, 'temperature': 50, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 212, 'temperature': 27, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 144, 'temperature': 28, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 175, 'temperature': 16, 'type': 'Earth analog', 'position': 11},
#  {'size': 131, 'temperature': 29, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 136, 'temperature': -46, 'type': 'Earth analog', 'position': 13},
#  {'size': 101, 'temperature': -73, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 150, 'temperature': -99, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 112, 'temperature': 235, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 125, 'temperature': 205, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 173, 'temperature': 121, 'type': 'Carbon planet', 'position': 3},
#  {'size': 138, 'temperature': 103, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 173, 'temperature': 97, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 175, 'temperature': 83, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 195, 'temperature': 69, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 185, 'temperature': 42, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 198, 'temperature': 56, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 153, 'temperature': 46, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 169, 'temperature': 36, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 127, 'temperature': -4, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 159,
#   'temperature': -46,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 155, 'temperature': -89, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 146, 'temperature': -95, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 157, 'temperature': 252, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 130, 'temperature': 190, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 138, 'temperature': 130, 'type': 'Gas giant', 'position': 3},
#  {'size': 154, 'temperature': 91, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 182, 'temperature': 65, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 213, 'temperature': 79, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 176, 'temperature': 79, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 239, 'temperature': 36, 'type': 'Earth analog', 'position': 8},
#  {'size': 180, 'temperature': 51, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 229, 'temperature': 47, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 195, 'temperature': 30, 'type': 'Helium planet', 'position': 11},
#  {'size': 177, 'temperature': -6, 'type': 'Gas giant', 'position': 12},
#  {'size': 158, 'temperature': -48, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 122, 'temperature': -87, 'type': 'Ammonia planet', 'position': 14},
#  {'size': 97,
#   'temperature': -105,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 157, 'temperature': 248, 'type': 'Gas giant', 'position': 1},
#  {'size': 160, 'temperature': 187, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 135, 'temperature': 152, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 162, 'temperature': 104, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 185, 'temperature': 80, 'type': 'Helium planet', 'position': 5},
#  {'size': 154, 'temperature': 88, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 186, 'temperature': 76, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 226, 'temperature': 35, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 198, 'temperature': 33, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 231, 'temperature': 34, 'type': 'Helium planet', 'position': 10},
#  {'size': 145, 'temperature': 30, 'type': 'Helium planet', 'position': 11},
#  {'size': 150, 'temperature': 20, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 155,
#   'temperature': -46,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 126, 'temperature': -70, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 157, 'temperature': -101, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 102, 'temperature': 249, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 164, 'temperature': 190, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 164, 'temperature': 127, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 196, 'temperature': 109, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 205, 'temperature': 63, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 181, 'temperature': 84, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 192, 'temperature': 64, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 210, 'temperature': 47, 'type': 'Ammonia planet', 'position': 8},
#  {'size': 177, 'temperature': 34, 'type': 'Earth analog', 'position': 9},
#  {'size': 168, 'temperature': 47, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 200, 'temperature': 9, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 155, 'temperature': -10, 'type': 'Earth analog', 'position': 12},
#  {'size': 163, 'temperature': -22, 'type': 'Gas giant', 'position': 13},
#  {'size': 147, 'temperature': -51, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 117, 'temperature': -115, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 114, 'temperature': 233, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 144, 'temperature': 195, 'type': 'Eccentric Jupiter', 'position': 2},
#  {'size': 163, 'temperature': 147, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 163, 'temperature': 70, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 204, 'temperature': 64, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 173, 'temperature': 81, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 185, 'temperature': 68, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 185, 'temperature': 52, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 220, 'temperature': 51, 'type': 'Helium planet', 'position': 9},
#  {'size': 157, 'temperature': 34, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 165, 'temperature': 28, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 159, 'temperature': -3, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 169,
#   'temperature': -40,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 133, 'temperature': -67, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 109,
#   'temperature': -106,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 162, 'temperature': 235, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 116, 'temperature': 207, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 149, 'temperature': 123, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 173, 'temperature': 96, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 141, 'temperature': 84, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 169, 'temperature': 78, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 244, 'temperature': 76, 'type': 'Gas giant', 'position': 7},
#  {'size': 158, 'temperature': 46, 'type': 'Gas giant', 'position': 8},
#  {'size': 168, 'temperature': 39, 'type': 'Eccentric Jupiter', 'position': 9},
#  {'size': 208, 'temperature': 37, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 161, 'temperature': 14, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 171, 'temperature': 20, 'type': 'Gas giant', 'position': 12},
#  {'size': 142, 'temperature': -50, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 144,
#   'temperature': -74,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 105, 'temperature': -109, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 146, 'temperature': 224, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 150, 'temperature': 184, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 153, 'temperature': 131, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 144, 'temperature': 70, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 186, 'temperature': 71, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 200, 'temperature': 74, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 243, 'temperature': 49, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 235, 'temperature': 64, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 224, 'temperature': 55, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 189, 'temperature': 48, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 197, 'temperature': 4, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 183, 'temperature': 25, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 160, 'temperature': -13, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 129, 'temperature': -75, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 151, 'temperature': -129, 'type': 'Carbon planet', 'position': 15},
#  {'size': 128, 'temperature': 244, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 116, 'temperature': 200, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 124, 'temperature': 120, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 187, 'temperature': 86, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 216, 'temperature': 69, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 192, 'temperature': 84, 'type': 'Chthonian planet', 'position': 6},
#  {'size': 163, 'temperature': 64, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 162, 'temperature': 32, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 176, 'temperature': 43, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 213, 'temperature': 49, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 193, 'temperature': 22, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 145, 'temperature': 12, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 135, 'temperature': -31, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 134, 'temperature': -63, 'type': 'Helium planet', 'position': 14},
#  {'size': 152, 'temperature': -97, 'type': 'Chthonian planet', 'position': 15},
#  {'size': 121, 'temperature': 239, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 134, 'temperature': 171, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 178, 'temperature': 130, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 127, 'temperature': 104, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 133, 'temperature': 64, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 157, 'temperature': 82, 'type': 'Helium planet', 'position': 6},
#  {'size': 181, 'temperature': 59, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 222, 'temperature': 46, 'type': 'Helium planet', 'position': 8},
#  {'size': 183, 'temperature': 51, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 199, 'temperature': 27, 'type': 'Gas giant', 'position': 10},
#  {'size': 138, 'temperature': 12, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 172, 'temperature': 23, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 161, 'temperature': -39, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 143, 'temperature': -90, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 155,
#   'temperature': -103,
#   'type': 'Eccentric Jupiter',
#   'position': 15},
#  {'size': 135, 'temperature': 233, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 164, 'temperature': 172, 'type': 'Forest planet', 'position': 2},
#  {'size': 116, 'temperature': 145, 'type': 'Forest planet', 'position': 3},
#  {'size': 197, 'temperature': 71, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 166, 'temperature': 66, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 186, 'temperature': 81, 'type': 'Ammonia planet', 'position': 6},
#  {'size': 194, 'temperature': 45, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 193, 'temperature': 68, 'type': 'Gas giant', 'position': 8},
#  {'size': 174, 'temperature': 25, 'type': 'Ammonia planet', 'position': 9},
#  {'size': 194, 'temperature': 11, 'type': 'Gas giant', 'position': 10},
#  {'size': 190, 'temperature': 9, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 141, 'temperature': 19, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 168, 'temperature': -34, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 155, 'temperature': -90, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 131, 'temperature': -120, 'type': 'Gas giant', 'position': 15},
#  {'size': 171, 'temperature': 226, 'type': 'Carbon planet', 'position': 1},
#  {'size': 119, 'temperature': 209, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 176, 'temperature': 130, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 122, 'temperature': 109, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 213, 'temperature': 91, 'type': 'Carbon planet', 'position': 5},
#  {'size': 223, 'temperature': 86, 'type': 'Helium planet', 'position': 6},
#  {'size': 168, 'temperature': 50, 'type': 'Gas giant', 'position': 7},
#  {'size': 227, 'temperature': 58, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 232, 'temperature': 56, 'type': 'Helium planet', 'position': 9},
#  {'size': 174, 'temperature': 18, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 200, 'temperature': 11, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 133, 'temperature': 12, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 151, 'temperature': -25, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 144, 'temperature': -62, 'type': 'Chthonian planet', 'position': 14},
#  {'size': 101, 'temperature': -107, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 169, 'temperature': 238, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 135, 'temperature': 180, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 176, 'temperature': 142, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 182, 'temperature': 107, 'type': 'Gas giant', 'position': 4},
#  {'size': 191, 'temperature': 63, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 158, 'temperature': 85, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 181, 'temperature': 46, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 224, 'temperature': 44, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 196, 'temperature': 23, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 146, 'temperature': 13, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 176, 'temperature': 15, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 182, 'temperature': 12, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 125, 'temperature': -28, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 125, 'temperature': -63, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 151,
#   'temperature': -103,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 150, 'temperature': 256, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 116, 'temperature': 175, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 141, 'temperature': 133, 'type': 'Eccentric Jupiter', 'position': 3},
#  {'size': 135, 'temperature': 77, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 212, 'temperature': 89, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 239, 'temperature': 81, 'type': 'Forest planet', 'position': 6},
#  {'size': 231, 'temperature': 54, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 241, 'temperature': 68, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 152, 'temperature': 35, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 210, 'temperature': 18, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 172, 'temperature': 8, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 181, 'temperature': -9, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 119, 'temperature': -44, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 113, 'temperature': -72, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 104, 'temperature': -93, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 149, 'temperature': 223, 'type': 'Helium planet', 'position': 1},
#  {'size': 116, 'temperature': 171, 'type': 'Earth analog', 'position': 2},
#  {'size': 180, 'temperature': 149, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 167, 'temperature': 102, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 223, 'temperature': 61, 'type': 'Earth analog', 'position': 5},
#  {'size': 155, 'temperature': 75, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 177, 'temperature': 70, 'type': 'Chthonian planet', 'position': 7},
#  {'size': 238, 'temperature': 37, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 217, 'temperature': 27, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 180, 'temperature': 26, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 144, 'temperature': 5, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 131, 'temperature': 5, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 153, 'temperature': -17, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 135, 'temperature': -57, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 158,
#   'temperature': -129,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 132, 'temperature': 238, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 147, 'temperature': 187, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 140, 'temperature': 130, 'type': 'Carbon planet', 'position': 3},
#  {'size': 200, 'temperature': 90, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 222, 'temperature': 99, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 166, 'temperature': 78, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 235, 'temperature': 45, 'type': 'Eccentric Jupiter', 'position': 7},
#  {'size': 174, 'temperature': 40, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 203, 'temperature': 33, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 186, 'temperature': 48, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 203, 'temperature': 7, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 150, 'temperature': 27, 'type': 'Ammonia planet', 'position': 12},
#  {'size': 169, 'temperature': -14, 'type': 'Gas giant', 'position': 13},
#  {'size': 111, 'temperature': -66, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 125, 'temperature': -91, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 99, 'temperature': 222, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 155, 'temperature': 198, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 140, 'temperature': 137, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 177, 'temperature': 81, 'type': 'Eccentric Jupiter', 'position': 4},
#  {'size': 228, 'temperature': 95, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 150, 'temperature': 70, 'type': 'Eccentric Jupiter', 'position': 6},
#  {'size': 217, 'temperature': 78, 'type': 'Gas giant', 'position': 7},
#  {'size': 185, 'temperature': 43, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 205, 'temperature': 35, 'type': 'Forest planet', 'position': 9},
#  {'size': 167, 'temperature': 45, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 172, 'temperature': 36, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 171, 'temperature': 17, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 147, 'temperature': -19, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 141, 'temperature': -70, 'type': 'Helium planet', 'position': 14},
#  {'size': 112, 'temperature': -107, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 115, 'temperature': 226, 'type': 'Eccentric Jupiter', 'position': 1},
#  {'size': 136, 'temperature': 182, 'type': 'Gas giant', 'position': 2},
#  {'size': 177, 'temperature': 138, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 187, 'temperature': 101, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 218, 'temperature': 97, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 182, 'temperature': 87, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 205, 'temperature': 53, 'type': 'Gas giant', 'position': 7},
#  {'size': 195, 'temperature': 65, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 174, 'temperature': 28, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 149, 'temperature': 35, 'type': 'Gas giant', 'position': 10},
#  {'size': 193, 'temperature': 18, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 146, 'temperature': 6, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 147, 'temperature': -16, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 151, 'temperature': -63, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 129, 'temperature': -100, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 114, 'temperature': 245, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 138, 'temperature': 193, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 164, 'temperature': 128, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 165, 'temperature': 108, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 219, 'temperature': 63, 'type': 'Ammonia planet', 'position': 5},
#  {'size': 160, 'temperature': 73, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 195, 'temperature': 50, 'type': 'Eccentric Jupiter', 'position': 7},
#  {'size': 207, 'temperature': 55, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 178, 'temperature': 33, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 171, 'temperature': 23, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 201, 'temperature': 7, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 179, 'temperature': 24, 'type': 'Helium planet', 'position': 12},
#  {'size': 133, 'temperature': -12, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 104, 'temperature': -68, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 96, 'temperature': -102, 'type': 'Helium planet', 'position': 15},
#  {'size': 156, 'temperature': 228, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 116, 'temperature': 178, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 149, 'temperature': 128, 'type': 'Ocean planet', 'position': 3},
#  {'size': 204, 'temperature': 77, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 181, 'temperature': 83, 'type': 'Brown dwarf', 'position': 5},
#  {'size': 185, 'temperature': 85, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 212, 'temperature': 79, 'type': 'Earth analog', 'position': 7},
#  {'size': 170, 'temperature': 57, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 162, 'temperature': 50, 'type': 'Chthonian planet', 'position': 9},
#  {'size': 203, 'temperature': 29, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 189, 'temperature': 20, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 139, 'temperature': 9, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 126, 'temperature': -43, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 145, 'temperature': -64, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 133, 'temperature': -126, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 164, 'temperature': 228, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 119, 'temperature': 183, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 120, 'temperature': 131, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 207, 'temperature': 80, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 195, 'temperature': 88, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 177, 'temperature': 88, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 187, 'temperature': 51, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 224, 'temperature': 68, 'type': 'Eccentric Jupiter', 'position': 8},
#  {'size': 212, 'temperature': 58, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 186, 'temperature': 24, 'type': 'Gas giant', 'position': 10},
#  {'size': 154, 'temperature': 21, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 133, 'temperature': 3, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 156, 'temperature': -39, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 148, 'temperature': -61, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 157, 'temperature': -112, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 111, 'temperature': 221, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 114, 'temperature': 191, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 124, 'temperature': 156, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 125, 'temperature': 106, 'type': 'Chthonian planet', 'position': 4},
#  {'size': 178, 'temperature': 83, 'type': 'Ammonia planet', 'position': 5},
#  {'size': 200, 'temperature': 85, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 156, 'temperature': 41, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 231, 'temperature': 57, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 216, 'temperature': 56, 'type': 'Carbon planet', 'position': 9},
#  {'size': 147, 'temperature': 37, 'type': 'Eccentric Jupiter', 'position': 10},
#  {'size': 181, 'temperature': 17, 'type': 'Brown dwarf', 'position': 11},
#  {'size': 133, 'temperature': 0, 'type': 'Brown dwarf', 'position': 12},
#  {'size': 121,
#   'temperature': -23,
#   'type': 'Eccentric Jupiter',
#   'position': 13},
#  {'size': 153, 'temperature': -85, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 138, 'temperature': -108, 'type': 'Brown dwarf', 'position': 15},
#  {'size': 151, 'temperature': 244, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 166, 'temperature': 182, 'type': 'Chthonian planet', 'position': 2},
#  {'size': 158, 'temperature': 154, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 193, 'temperature': 73, 'type': 'Gas giant', 'position': 4},
#  {'size': 212, 'temperature': 62, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 174, 'temperature': 83, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 191, 'temperature': 65, 'type': 'Ammonia planet', 'position': 7},
#  {'size': 191, 'temperature': 50, 'type': 'Chthonian planet', 'position': 8},
#  {'size': 205, 'temperature': 27, 'type': 'Carbon planet', 'position': 9},
#  {'size': 143, 'temperature': 19, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 169, 'temperature': 9, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 178, 'temperature': 21, 'type': 'Chthonian planet', 'position': 12},
#  {'size': 170, 'temperature': -31, 'type': 'Chthonian planet', 'position': 13},
#  {'size': 163,
#   'temperature': -58,
#   'type': 'Eccentric Jupiter',
#   'position': 14},
#  {'size': 147,
#   'temperature': -110,
#   'type': 'Chthonian planet',
#   'position': 15},
#  {'size': 101, 'temperature': 258, 'type': 'Brown dwarf', 'position': 1},
#  {'size': 168, 'temperature': 200, 'type': 'Helium planet', 'position': 2},
#  {'size': 175, 'temperature': 147, 'type': 'Brown dwarf', 'position': 3},
#  {'size': 176, 'temperature': 70, 'type': 'Brown dwarf', 'position': 4},
#  {'size': 223, 'temperature': 84, 'type': 'Eccentric Jupiter', 'position': 5},
#  {'size': 217, 'temperature': 76, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 205, 'temperature': 54, 'type': 'Brown dwarf', 'position': 7},
#  {'size': 229, 'temperature': 61, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 237, 'temperature': 32, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 205, 'temperature': 27, 'type': 'Chthonian planet', 'position': 10},
#  {'size': 137, 'temperature': 21, 'type': 'Chthonian planet', 'position': 11},
#  {'size': 180, 'temperature': 4, 'type': 'Eccentric Jupiter', 'position': 12},
#  {'size': 157, 'temperature': -33, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 105, 'temperature': -82, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 152, 'temperature': -100, 'type': 'Earth analog', 'position': 15},
#  {'size': 115, 'temperature': 244, 'type': 'Chthonian planet', 'position': 1},
#  {'size': 155, 'temperature': 184, 'type': 'Brown dwarf', 'position': 2},
#  {'size': 137, 'temperature': 128, 'type': 'Chthonian planet', 'position': 3},
#  {'size': 187, 'temperature': 72, 'type': 'Earth analog', 'position': 4},
#  {'size': 227, 'temperature': 93, 'type': 'Chthonian planet', 'position': 5},
#  {'size': 216, 'temperature': 87, 'type': 'Brown dwarf', 'position': 6},
#  {'size': 192, 'temperature': 61, 'type': 'Gas giant', 'position': 7},
#  {'size': 177, 'temperature': 36, 'type': 'Brown dwarf', 'position': 8},
#  {'size': 159, 'temperature': 48, 'type': 'Brown dwarf', 'position': 9},
#  {'size': 209, 'temperature': 42, 'type': 'Brown dwarf', 'position': 10},
#  {'size': 199, 'temperature': 21, 'type': 'Eccentric Jupiter', 'position': 11},
#  {'size': 166, 'temperature': 6, 'type': 'Helium planet', 'position': 12},
#  {'size': 154, 'temperature': -28, 'type': 'Brown dwarf', 'position': 13},
#  {'size': 141, 'temperature': -88, 'type': 'Brown dwarf', 'position': 14},
#  {'size': 95, 'temperature': -109, 'type': 'Chthonian planet', 'position': 15}]

# %%
len(planets)
# Out:
# 750

# %%
planets[1]
# Out:
# {'size': 174, 'temperature': 180, 'type': 'Brown dwarf', 'position': 2}

# %%
def all_unique(all_planets):
    seen = list()
    return not any(i in seen or seen.append(i) for i in all_planets)

# %%
print("Are all images unique?", all_unique(planets))
# Add token Id to each image
i = 1
for item in planets:
    item["tokenId"] = i
    i = i + 1
   
print(all_planets)
# Out:
# Are all images unique? True
# []

# %%
os.mkdir(f'./metadata2')

METADATA_FILE_NAME = './metadata/all-traits.json'; 
with open(METADATA_FILE_NAME, 'w') as outfile:
    json.dump(planets, outfile, indent=4)

# %%
#### Generate Metadata for each Image    

f = open('./metadata/all-traits.json',) 
data = json.load(f)

# Changes this IMAGES_BASE_URL to yours 
IMAGES_BASE_URL = "https://gateway.pinata.cloud/ipfs/QmcV5ZbVHnQGjMqY8V7UWxX9cs3FehU8jT32FmNQVMs3ns/"
PROJECT_NAME = "NoGame"

def getAttribute(key, value):
    return {
        "trait_type": key,
        "value": value
    }
for i in data:
    token_id = i['tokenId']
    token = {
        "image": IMAGES_BASE_URL + str(token_id%15) + '.webp',
        "tokenId": token_id,
        "name": PROJECT_NAME + ' #' + str(token_id),
        "attributes": []
    }
    token["attributes"].append(getAttribute("size", i["size"]))
    token["attributes"].append(getAttribute("temperature", i["temperature"]))
    token["attributes"].append(getAttribute("type", i["type"]))
    token["attributes"].append(getAttribute("position", i["position"]))

    with open('./metadata2/' + str(token_id), 'w') as outfile:
        json.dump(token, outfile, indent=4)
f.close()

# %%
s = [105,112,102,115,58,47,47,81,109,98,87,78,103,117,89,106,85,115,53,101,50,102,55,88,119,113,65,106,54,121,72,69,119,111,74,109,104,89,78,121,72,78,78,90,122,105,102,56,78,109,56,53,68,47]
out = ""
for i in s:
    out = out + str(i) + " "

# %%
len(out)
# Out:
# 186
